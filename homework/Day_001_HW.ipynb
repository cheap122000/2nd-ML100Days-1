# %% [markdown]
# # 作業1：
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 挑選的資料：[Solar generation and demand Italy 2015-2016](https://www.kaggle.com/arielcedola/solar-generation-and-demand-italy-20152016)
#
# ### 1. 你選的這組資料為何重要
# 目前能源議題越來越受到重視，而太陽能相關技術有許多的進步空間，而自己本身也在做發電量的論文研究，所以多參考國內外的文章和資料是有幫助的
#
# ### 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# 提供者：Ariel Cedola
# 主要從ENTSO-E Transparency網站下載資料集來收集資料
#
# ### 3. 蒐集而來的資料型態為何
# 資料型態：csv
#
# ### 4. 這組資料想解決的問題如何評估
# 想要改進目前對於用電量負荷的預測，
# 資料集的網站有提供不同國家/地區的日前總負荷預測與實際總負荷之間的最新比較，
# 而我們要如何運用這些資料做更精確預測？進而改善未來用電負荷問題
#
#
# # 作業2：
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# ### 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 多久時間或多快時間達成高於平常業績量的10%、20%不等(自行設定)？
# 如何用"最有效"的方法去提升業績，而且在"時間與效率"上達成平衡？
#
# ### 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 從車隊系統調出現有收集的資料，如果沒有收集的就從每部車加裝設備去蒐集目前沒有的資料，主要需要收集行車距離、平均時速、單趟載客時間、車子加油時間點、無載客閒置時間與次數等等，或著是顧客意見評分表，如果要思考到影響更深遠的，要額外收集氣象局天氣數據、交通局道路狀況、有無特殊節日或活動等等，去看說這些狀況對於業績影響的相關程度
#
# ### 3. 蒐集而來的資料型態為何
# 與車子有關的資料型態大多是時間與數字相關的結構化資料，而氣象、交通相關資料有可能會收集到半結構、非結構化資料(json格式、影像、影片等等)
#
# ### 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 要在時間、效率上達到提升業績的目標，有以下三點：
# 1.與車子相關因素：觀看哪個部分實際影響到業績最大的因素(EX：無載客閒置時間與次數，導致收入無法提高)，試著去做改善(EX：車隊激勵機制、排名賽績效獎勵、分析跑的路線與區域是否為鬧區或載客率高等等)
# 2.不可控因素(天氣、交通)：極端氣候會提高顧客想搭車的機率，特殊節慶活動會有大量人潮進而提升載客需求，避開塞車路線提高行車效率等等都有可能影響
# 3.乘客：最大因素還是在人，同業競爭、服務品質、效率、方便性都是在顧客考量範圍內，透過精準行銷提高顧客黏著度，有效累積常客數量，提供優惠活動、服務等等影響業績很大的因素
#
# # 作業3：

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import math
def mean_squared_error(y,yp):
    """
    請完成這個 Function 後往下執行
    """
    
    mse = MSE = sum((y - yp)**2) / len(y)
    #mse = MSE = sum(math.pow(y - yp,2)) / len(y)
    return mse

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 12.619

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 233.764
# The Mean absolute error is 12.573
